# %% [markdown]
# # EDA on general features & after tokenization

# %% [markdown]
# ## Import data & modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("drive/MyDrive/Final Project/story_data_new_feats.csv")

# %% [markdown]
# ## Light general exploration

# %%
print(df.columns)
# Out:
# Index(['story_id', 'title', 'author', 'contest_num', 'won_contest',
#        'num_likes', 'num_comments', 'story_html', 'date_published', 'num_sent',
#        'story_sent', 'sent_lengths', 'sent_avg_length', 'sent_words',
#        'story_word_toks', 'words', 'punctuation', 'num_words', 'unique_words',
#        'num_unique_words', 'unique_words_percent', 'text_str', 'age',
#        'words_exist_per_cent', 'num_cats', 'cat_School', 'cat_Creative',
#        'cat_Age', 'cat_Happy', 'cat_Thriller', 'cat_Friendship', 'cat_East',
#        'cat_Inspirational', 'cat_Christian', 'cat_Bedtime', 'cat_Drama',
#        'cat_Horror', 'cat_Lesbian', 'cat_High', 'cat_Science', 'cat_American',
#        'cat_Speculative', 'cat_Funny', 'cat_Adventure', 'cat_Nonfiction',
#        'cat_African', 'cat_Christmas', 'cat_Teens', 'cat_Fantasy',
#        'cat_Holiday', 'cat_Western', 'cat_Young', 'cat_Coming', 'cat_Suspense',
#        'cat_Romance', 'cat_Urban', 'cat_Latinx', 'cat_Desi', 'cat_Asian',
#        'cat_Black', 'cat_Sad', 'cat_Kids', 'cat_People', 'cat_Color',
#        'cat_Fiction', 'cat_Contemporary', 'cat_Mystery', 'cat_Adult',
#        'cat_Transgender', 'cat_Historical', 'cat_Middle', 'cat_Gay',
#        'cat_Indigenous', 'cat_Crime', 'shortlisted',
#        'sentiment_POSITIVE_no_prepro', 'sentiment_NEGATIVE_no_prepro',
#        'sentiment_hf_text', 'emotion_all', 'emotion_anger', 'emotion_fear',
#        'emotion_joy', 'emotion_love', 'emotion_sadness', 'emotion_surprise',
#        'lemmatized_parag', 'text_str_lem'],
#       dtype='object')

# %%
print('Dataset dimensions:', df.shape)
print('Does the dataset contain NA?', df.isna().any().any())
print('Data types in dataset:')
print(df.dtypes.value_counts())
# Out:
# Dataset dimensions: (18248, 87)
# Does the dataset contain NA? True
# Data types in dataset:
# int64      59
# object     16
# float64    12
# dtype: int64

# %%
# missing values
for c in df.columns:
  if df[c].isna().sum(axis=0)>0:
    print(c, df[c].isna().sum(axis=0))
# Out:
# author 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18248 entries, 0 to 18247
# Data columns (total 87 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   story_id                      18248 non-null  object
#  1   title                         18248 non-null  object
#  2   author                        18246 non-null  object
#  3   contest_num                   18248 non-null  int64
#  4   won_contest                   18248 non-null  int64
#  5   num_likes                     18248 non-null  int64
#  6   num_comments                  18248 non-null  int64
#  7   story_html                    18248 non-null  object
#  8   date_published                18248 non-null  object
#  9   num_sent                      18248 non-null  int64
#  10  story_sent                    18248 non-null  object
#  11  sent_lengths                  18248 non-null  object
#  12  sent_avg_length               18248 non-null  float64
#  13  sent_words                    18248 non-null  object
#  14  story_word_toks               18248 non-null  object
#  15  words                         18248 non-null  object
#  16  punctuation                   18248 non-null  object
#  17  num_words                     18248 non-null  int64
#  18  unique_words                  18248 non-null  object
#  19  num_unique_words              18248 non-null  int64
#  20  unique_words_percent          18248 non-null  float64
#  21  text_str                      18248 non-null  object
#  22  age                           18248 non-null  int64
#  23  words_exist_per_cent          18248 non-null  float64
#  24  num_cats                      18248 non-null  int64
#  25  cat_School                    18248 non-null  int64
#  26  cat_Creative                  18248 non-null  int64
#  27  cat_Age                       18248 non-null  int64
#  28  cat_Happy                     18248 non-null  int64
#  29  cat_Thriller                  18248 non-null  int64
#  30  cat_Friendship                18248 non-null  int64
#  31  cat_East                      18248 non-null  int64
#  32  cat_Inspirational             18248 non-null  int64
#  33  cat_Christian                 18248 non-null  int64
#  34  cat_Bedtime                   18248 non-null  int64
#  35  cat_Drama                     18248 non-null  int64
#  36  cat_Horror                    18248 non-null  int64
#  37  cat_Lesbian                   18248 non-null  int64
#  38  cat_High                      18248 non-null  int64
#  39  cat_Science                   18248 non-null  int64
#  40  cat_American                  18248 non-null  int64
#  41  cat_Speculative               18248 non-null  int64
#  42  cat_Funny                     18248 non-null  int64
#  43  cat_Adventure                 18248 non-null  int64
#  44  cat_Nonfiction                18248 non-null  int64
#  45  cat_African                   18248 non-null  int64
#  46  cat_Christmas                 18248 non-null  int64
#  47  cat_Teens                     18248 non-null  int64
#  48  cat_Fantasy                   18248 non-null  int64
#  49  cat_Holiday                   18248 non-null  int64
#  50  cat_Western                   18248 non-null  int64
#  51  cat_Young                     18248 non-null  int64
#  52  cat_Coming                    18248 non-null  int64
#  53  cat_Suspense                  18248 non-null  int64
#  54  cat_Romance                   18248 non-null  int64
#  55  cat_Urban                     18248 non-null  int64
#  56  cat_Latinx                    18248 non-null  int64
#  57  cat_Desi                      18248 non-null  int64
#  58  cat_Asian                     18248 non-null  int64
#  59  cat_Black                     18248 non-null  int64
#  60  cat_Sad                       18248 non-null  int64
#  61  cat_Kids                      18248 non-null  int64
#  62  cat_People                    18248 non-null  int64
#  63  cat_Color                     18248 non-null  int64
#  64  cat_Fiction                   18248 non-null  int64
#  65  cat_Contemporary              18248 non-null  int64
#  66  cat_Mystery                   18248 non-null  int64
#  67  cat_Adult                     18248 non-null  int64
#  68  cat_Transgender               18248 non-null  int64
#  69  cat_Historical                18248 non-null  int64
#  70  cat_Middle                    18248 non-null  int64
#  71  cat_Gay                       18248 non-null  int64
#  72  cat_Indigenous                18248 non-null  int64
#  73  cat_Crime                     18248 non-null  int64
#  74  shortlisted                   18248 non-null  int64
#  75  sentiment_POSITIVE_no_prepro  18248 non-null  float64
#  76  sentiment_NEGATIVE_no_prepro  18248 non-null  float64
#  77  sentiment_hf_text             18248 non-null  float64
#  78  emotion_all                   18248 non-null  object
#  79  emotion_anger                 18248 non-null  float64
#  80  emotion_fear                  18248 non-null  float64
#  81  emotion_joy                   18248 non-null  float64
#  82  emotion_love                  18248 non-null  float64
#  83  emotion_sadness               18248 non-null  float64
#  84  emotion_surprise              18248 non-null  float64
#  85  lemmatized_parag              18248 non-null  object
#  86  text_str_lem                  18248 non-null  object
# dtypes: float64(12), int64(59), object(16)
# memory usage: 12.1+ MB

# %%
numerical = ['num_likes', 'num_comments', 'num_sent', 'sent_avg_length', 'num_words', 
             'num_unique_words', 'unique_words_percent', 'age', 'num_cats',
             'shortlisted', 'sentiment_POSITIVE_no_prepro', 
             'sentiment_NEGATIVE_no_prepro', 'sentiment_hf_text',
             'emotion_anger', 'emotion_fear', 'emotion_joy', 'emotion_love', 
             'emotion_sadness', 'emotion_surprise', ]

# %%
df[numerical].describe()
# Out:
#           num_likes  num_comments      num_sent  sent_avg_length  \
# count  18248.000000  18248.000000  18248.000000     18248.000000
# mean      14.138700      4.295758    119.869739        19.325097
# std       18.742977     17.676338     54.617152        20.474949
# min        0.000000      0.000000      1.000000         4.197222
# 25%        7.000000      0.000000     80.000000        14.865331
# 50%       10.000000      1.000000    108.000000        17.545455
# 75%       14.000000      3.000000    151.000000        20.960132
# max      503.000000    629.000000    414.000000      1459.000000
#
#           num_words  num_unique_words  unique_words_percent           age  \
# count  18248.000000      18248.000000          18248.000000  18248.000000
# mean    1772.493205        653.386234              0.381320    502.618972
# std      663.515601        195.248741              0.053579    160.524603
# min      411.000000        187.000000              0.143804    124.000000
# 25%     1191.000000        494.000000              0.343355    430.000000
# 50%     1569.000000        607.000000              0.380890    518.000000
# 75%     2265.000000        793.000000              0.417809    621.000000
# max     4620.000000       1507.000000              0.638215   1154.000000
#
#            num_cats   shortlisted  sentiment_POSITIVE_no_prepro  \
# count  18248.000000  18248.000000                  18248.000000
# mean       2.950460      0.010302                      0.659674
# std        1.175209      0.100980                      0.177446
# min        1.000000      0.000000                      0.090909
# 25%        2.000000      0.000000                      0.547368
# 50%        3.000000      0.000000                      0.666667
# 75%        3.000000      0.000000                      0.750000
# max        8.000000      1.000000                      1.000000
#
#        sentiment_NEGATIVE_no_prepro  sentiment_hf_text  emotion_anger  \
# count                  18248.000000       18248.000000   18248.000000
# mean                       0.390804          -0.317295       0.353911
# std                        0.140819           0.948122       0.095069
# min                        0.014925          -1.000000       0.000000
# 25%                        0.307585          -1.000000       0.289474
# 50%                        0.341772          -1.000000       0.352941
# 75%                        0.500000           1.000000       0.416412
# max                        0.909091           1.000000       0.949153
#
#        emotion_fear   emotion_joy  emotion_love  emotion_sadness  \
# count  18248.000000  18248.000000  18248.000000     18248.000000
# mean       0.197025      0.322536      0.026769         0.090286
# std        0.093746      0.103808      0.025684         0.050729
# min        0.000000      0.000000      0.000000         0.000000
# 25%        0.129310      0.250000      0.009050         0.054209
# 50%        0.185265      0.313901      0.020619         0.082070
# 75%        0.253185      0.386872      0.038144         0.116902
# max        0.673469      1.000000      0.315789         0.500000
#
#        emotion_surprise
# count      18248.000000
# mean           0.010222
# std            0.013392
# min            0.000000
# 25%            0.000000
# 50%            0.007463
# 75%            0.015385
# max            0.500000

# %%
with pd.option_context('display.max_rows', 1, 'display.max_columns', None): 
    display(df.sample(1))
# Out:
#      story_id    title        author  contest_num  won_contest  num_likes  \
# 8909   qsrre0  Capture  Meggysa Nine           81            0          7
#
#       num_comments                                         story_html  \
# 8909             0  <article class="font-alt submission-content sp...
#
#            date_published  num_sent  \
# 8909  2021-02-17 05:18:00        61
#
#                                              story_sent  \
# 8909  ["\nThirteen hundred — that's how my ex-milita...
#
#                                            sent_lengths  sent_avg_length  \
# 8909  [39 12 22 31 16  8 10 24 15  7 16 34 29 15 22 ...        19.032787
#
#                                              sent_words  \
# 8909  [list(['Thirteen', 'hundred', '—', 'that', "'s...
#
#                                         story_word_toks  \
# 8909  ['Thirteen', 'hundred', '—', 'that', "'s", 'ho...
#
#                                                   words  \
# 8909  ['Thirteen' 'hundred' 'that' ... 'she' 'softly...
#
#                                             punctuation  num_words  \
# 8909  ['—' '—' '.' '.' '.' '.' '.' '.' '.' '.' '.' '...       1063
#
#                                            unique_words  num_unique_words  \
# 8909  {'from', 'The', 'polaroids', 'uttered', 'beaut...               452
#
#       unique_words_percent                                           text_str  \
# 8909              0.425212  \nThirteen hundred — that's how my ex-military...
#
#       age  words_exist_per_cent  num_cats  cat_School  cat_Creative  cat_Age  \
# 8909  595             93.023256         2           0             0        0
#
#       cat_Happy  cat_Thriller  cat_Friendship  cat_East  cat_Inspirational  \
# 8909          0             0               0         0                  0
#
#       cat_Christian  cat_Bedtime  cat_Drama  cat_Horror  cat_Lesbian  \
# 8909              0            0          0           0            0
#
#       cat_High  cat_Science  cat_American  cat_Speculative  cat_Funny  \
# 8909         0            0             0                0          0
#
#       cat_Adventure  cat_Nonfiction  cat_African  cat_Christmas  cat_Teens  \
# 8909              0               0            0              0          0
#
#       cat_Fantasy  cat_Holiday  cat_Western  cat_Young  cat_Coming  \
# 8909            0            0            0          0           0
#
#       cat_Suspense  cat_Romance  cat_Urban  cat_Latinx  cat_Desi  cat_Asian  \
# 8909             0            1          0           0         0          0
#
#       cat_Black  cat_Sad  cat_Kids  cat_People  cat_Color  cat_Fiction  \
# 8909          0        0         0           0          0            1
#
#       cat_Contemporary  cat_Mystery  cat_Adult  cat_Transgender  \
# 8909                 0            0          0                0
#
#       cat_Historical  cat_Middle  cat_Gay  cat_Indigenous  cat_Crime  \
# 8909               0           0        0               0          0
#
#       shortlisted  sentiment_POSITIVE_no_prepro  sentiment_NEGATIVE_no_prepro  \
# 8909            0                      0.957447                      0.042553
#
#       sentiment_hf_text                                        emotion_all  \
# 8909               -1.0  ['joy', 'joy', 'joy', 'joy', 'sadness', 'fear'...
#
#       emotion_anger  emotion_fear  emotion_joy  emotion_love  emotion_sadness  \
# 8909       0.180328      0.180328      0.52459       0.04918          0.04918
#
#       emotion_surprise                                   lemmatized_parag  \
# 8909          0.016393  ['', ' thirteen hundred — that be how -PRON- e...
#
#                                            text_str_lem
# 8909  \n thirteen hundred — that be how -PRON- ex - ...

# %% [markdown]
# ## Distributions

# %% [markdown]
# Distribution of numerical features:

# %%
my_j = int(len(numerical)/2)
f,ax=plt.subplots(my_j,2, figsize=(19,24), constrained_layout = True)
feat_iter=iter(numerical)
for i in range(my_j):
    for j in range(2):
      try:
        x = next(feat_iter)
        ax[i,j].hist(df[x], bins=50)
        ax[i,j].set_title(x)
      except StopIteration:
          pass

# %% [markdown]
# Distribution of target

# %%
threshold = 50
df[df.num_likes<threshold].boxplot(column='num_likes')

# %% [markdown]
# Distribution of categorical features:

# %%
categories = [col for col in df if col.startswith('cat')]
categories.remove('cat_Fiction')
# for cat in categories:
#   df.boxplot(column='num_likes', by=cat, vert=False)
#   plt.title(f'num_likes distribution per {cat}')
#   plt.suptitle('')
#   plt.show()

# %%
dfm = df[categories].melt()
dfm = dfm[dfm.value==1]
plot_df = (
    pd.crosstab(dfm['variable'], dfm['value'])
)
plot_df.plot.bar(figsize=(15,13))
# plt.tight_layout()
# plt.show()

# %%
target = 'num_likes'

# %%
my_j = int(len(categories)/5)

f,ax=plt.subplots(my_j,
                  5, 
                  figsize=(16,25), 
                  constrained_layout = True)
feat_iter=iter(categories)

for i in range(my_j):
    for j in range(5):
      try:
        x = next(feat_iter)
        df.groupby(x)[target].mean().sort_values().plot.bar(ax=ax[i,j])
        ax[i,j].set_title(f"{target} by {x} (means)")
      except StopIteration:
          pass

# %% [markdown]
# ## Against target

# %% [markdown]
# Correlation of numerical features with target

# %%
target = 'num_likes'
threshold = 400
print('Pearson correlation:')
for my_var in numerical:
  print(my_var ,'= ', df[df.num_likes<threshold][my_var].corr(df[df.num_likes<threshold][target]))
# Out:
# Pearson correlation:
# num_likes =  1.0
# num_comments =  0.6513481714797659
# num_sent =  -0.0019137670513435028
# sent_avg_length =  0.02518223044691615
# num_words =  0.013323691905360023
# num_unique_words =  0.0296463460519612
# unique_words_percent =  0.029235916357279984
# age =  -0.02145681608332524
# num_cats =  -0.006931574871593074
# shortlisted =  0.1299273756693547
# sentiment_POSITIVE_no_prepro =  0.06609148105097301
# sentiment_NEGATIVE_no_prepro =  -0.008973632169001294
# sentiment_hf_text =  -0.011688029337172876
# emotion_anger =  0.022198006033359797
# emotion_fear =  -0.011020410660537643
# emotion_joy =  -0.02980074611343543
# emotion_love =  0.01545099255006402
# emotion_sadness =  0.030522005256107314
# emotion_surprise =  -0.016438644040757983

# %%
print('spearman correlation:')
for my_var in numerical:
  print(my_var ,'= ', df[df.num_likes<threshold][my_var].corr(df[df.num_likes<threshold][target], method='spearman'))
# Out:
# spearman correlation:
# num_likes =  1.0
# num_comments =  0.5263455765956184
# num_sent =  0.014698769783223473
# sent_avg_length =  0.03482459631410506
# num_words =  0.03222692664283464
# num_unique_words =  0.058881608202076725
# unique_words_percent =  0.0337470483528916
# age =  -0.18518706978145094
# num_cats =  0.04040574922680849
# shortlisted =  0.15113157724460907
# sentiment_POSITIVE_no_prepro =  0.06118156064190844
# sentiment_NEGATIVE_no_prepro =  0.006470043665466252
# sentiment_hf_text =  -0.011335113864840573
# emotion_anger =  0.03291808670358443
# emotion_fear =  0.014230449420151179
# emotion_joy =  -0.03017725003173332
# emotion_love =  0.004371964597941588
# emotion_sadness =  -0.012967509225418287
# emotion_surprise =  -0.014411425190304137

# %%
target = 'num_likes'
my_j = int(len(numerical)/3)

f,ax=plt.subplots(my_j,
                  3, 
                  figsize=(30,20), 
                  constrained_layout = True)
feat_iter=iter(numerical)

for i in range(my_j):
    for j in range(3):
      try:
        x = next(feat_iter)
        ax[i,j].scatter(df[x], df[target])
        ax[i,j].set_title(f"{target} by {x} (means), {df[x].corr(df[target]):.3f}")
      except StopIteration:
          pass

# %% [markdown]
# Number of likes is our target, so it should be highly correlated with itself (threshold is offset).
#
# Number of comments, as suspected, is highly correlated as well.
#
# The length of the story doesn't seem to have much of a linear correlation with the target.

# %% [markdown]
# ## Correlation between features

# %%
def color_map(val):
    color = 'red' if float(val) < -0.4 else 'green' if float(val) > 0.2  else 'black'
    return 'color: %s' % color

corr = df[numerical].corr(method='spearman')
df_styled = corr.style.applymap(color_map)
df_styled
# Out:
# <style type="text/css">
# #T_2e403_row0_col0, #T_2e403_row0_col1, #T_2e403_row1_col0, #T_2e403_row1_col1, #T_2e403_row2_col2, #T_2e403_row2_col4, #T_2e403_row2_col5, #T_2e403_row2_col13, #T_2e403_row3_col3, #T_2e403_row4_col2, #T_2e403_row4_col4, #T_2e403_row4_col5, #T_2e403_row5_col2, #T_2e403_row5_col4, #T_2e403_row5_col5, #T_2e403_row6_col6, #T_2e403_row7_col7, #T_2e403_row8_col8, #T_2e403_row9_col9, #T_2e403_row10_col10, #T_2e403_row10_col12, #T_2e403_row10_col15, #T_2e403_row10_col16, #T_2e403_row11_col11, #T_2e403_row12_col10, #T_2e403_row12_col12, #T_2e403_row12_col15, #T_2e403_row12_col16, #T_2e403_row13_col2, #T_2e403_row13_col13, #T_2e403_row14_col14, #T_2e403_row15_col10, #T_2e403_row15_col12, #T_2e403_row15_col15, #T_2e403_row16_col10, #T_2e403_row16_col12, #T_2e403_row16_col16, #T_2e403_row17_col17, #T_2e403_row18_col18 {
#   color: green;
# }
# #T_2e403_row0_col2, #T_2e403_row0_col3, #T_2e403_row0_col4, #T_2e403_row0_col5, #T_2e403_row0_col6, #T_2e403_row0_col7, #T_2e403_row0_col8, #T_2e403_row0_col9, #T_2e403_row0_col10, #T_2e403_row0_col11, #T_2e403_row0_col12, #T_2e403_row0_col13, #T_2e403_row0_col14, #T_2e403_row0_col15, #T_2e403_row0_col16, #T_2e403_row0_col17, #T_2e403_row0_col18, #T_2e403_row1_col2, #T_2e403_row1_col3, #T_2e403_row1_col4, #T_2e403_row1_col5, #T_2e403_row1_col6, #T_2e403_row1_col7, #T_2e403_row1_col8, #T_2e403_row1_col9, #T_2e403_row1_col10, #T_2e403_row1_col11, #T_2e403_row1_col12, #T_2e403_row1_col13, #T_2e403_row1_col14, #T_2e403_row1_col15, #T_2e403_row1_col16, #T_2e403_row1_col17, #T_2e403_row1_col18, #T_2e403_row2_col0, #T_2e403_row2_col1, #T_2e403_row2_col7, #T_2e403_row2_col8, #T_2e403_row2_col9, #T_2e403_row2_col10, #T_2e403_row2_col11, #T_2e403_row2_col12, #T_2e403_row2_col14, #T_2e403_row2_col15, #T_2e403_row2_col16, #T_2e403_row2_col17, #T_2e403_row2_col18, #T_2e403_row3_col0, #T_2e403_row3_col1, #T_2e403_row3_col4, #T_2e403_row3_col5, #T_2e403_row3_col6, #T_2e403_row3_col7, #T_2e403_row3_col8, #T_2e403_row3_col9, #T_2e403_row3_col10, #T_2e403_row3_col11, #T_2e403_row3_col12, #T_2e403_row3_col13, #T_2e403_row3_col14, #T_2e403_row3_col15, #T_2e403_row3_col16, #T_2e403_row3_col17, #T_2e403_row3_col18, #T_2e403_row4_col0, #T_2e403_row4_col1, #T_2e403_row4_col3, #T_2e403_row4_col7, #T_2e403_row4_col8, #T_2e403_row4_col9, #T_2e403_row4_col10, #T_2e403_row4_col11, #T_2e403_row4_col12, #T_2e403_row4_col13, #T_2e403_row4_col14, #T_2e403_row4_col15, #T_2e403_row4_col16, #T_2e403_row4_col17, #T_2e403_row4_col18, #T_2e403_row5_col0, #T_2e403_row5_col1, #T_2e403_row5_col3, #T_2e403_row5_col6, #T_2e403_row5_col7, #T_2e403_row5_col8, #T_2e403_row5_col9, #T_2e403_row5_col10, #T_2e403_row5_col11, #T_2e403_row5_col12, #T_2e403_row5_col13, #T_2e403_row5_col14, #T_2e403_row5_col15, #T_2e403_row5_col16, #T_2e403_row5_col17, #T_2e403_row5_col18, #T_2e403_row6_col0, #T_2e403_row6_col1, #T_2e403_row6_col3, #T_2e403_row6_col5, #T_2e403_row6_col7, #T_2e403_row6_col8, #T_2e403_row6_col9, #T_2e403_row6_col10, #T_2e403_row6_col11, #T_2e403_row6_col12, #T_2e403_row6_col13, #T_2e403_row6_col14, #T_2e403_row6_col15, #T_2e403_row6_col16, #T_2e403_row6_col17, #T_2e403_row6_col18, #T_2e403_row7_col0, #T_2e403_row7_col1, #T_2e403_row7_col2, #T_2e403_row7_col3, #T_2e403_row7_col4, #T_2e403_row7_col5, #T_2e403_row7_col6, #T_2e403_row7_col8, #T_2e403_row7_col9, #T_2e403_row7_col10, #T_2e403_row7_col11, #T_2e403_row7_col12, #T_2e403_row7_col13, #T_2e403_row7_col14, #T_2e403_row7_col15, #T_2e403_row7_col16, #T_2e403_row7_col17, #T_2e403_row7_col18, #T_2e403_row8_col0, #T_2e403_row8_col1, #T_2e403_row8_col2, #T_2e403_row8_col3, #T_2e403_row8_col4, #T_2e403_row8_col5, #T_2e403_row8_col6, #T_2e403_row8_col7, #T_2e403_row8_col9, #T_2e403_row8_col10, #T_2e403_row8_col11, #T_2e403_row8_col12, #T_2e403_row8_col13, #T_2e403_row8_col14, #T_2e403_row8_col15, #T_2e403_row8_col16, #T_2e403_row8_col17, #T_2e403_row8_col18, #T_2e403_row9_col0, #T_2e403_row9_col1, #T_2e403_row9_col2, #T_2e403_row9_col3, #T_2e403_row9_col4, #T_2e403_row9_col5, #T_2e403_row9_col6, #T_2e403_row9_col7, #T_2e403_row9_col8, #T_2e403_row9_col10, #T_2e403_row9_col11, #T_2e403_row9_col12, #T_2e403_row9_col13, #T_2e403_row9_col14, #T_2e403_row9_col15, #T_2e403_row9_col16, #T_2e403_row9_col17, #T_2e403_row9_col18, #T_2e403_row10_col0, #T_2e403_row10_col1, #T_2e403_row10_col2, #T_2e403_row10_col3, #T_2e403_row10_col4, #T_2e403_row10_col5, #T_2e403_row10_col6, #T_2e403_row10_col7, #T_2e403_row10_col8, #T_2e403_row10_col9, #T_2e403_row10_col13, #T_2e403_row10_col14, #T_2e403_row10_col17, #T_2e403_row10_col18, #T_2e403_row11_col0, #T_2e403_row11_col1, #T_2e403_row11_col2, #T_2e403_row11_col3, #T_2e403_row11_col4, #T_2e403_row11_col5, #T_2e403_row11_col6, #T_2e403_row11_col7, #T_2e403_row11_col8, #T_2e403_row11_col9, #T_2e403_row11_col12, #T_2e403_row11_col13, #T_2e403_row11_col14, #T_2e403_row11_col15, #T_2e403_row11_ ...
#   color: black;
# }
# #T_2e403_row2_col3, #T_2e403_row2_col6, #T_2e403_row3_col2, #T_2e403_row4_col6, #T_2e403_row6_col2, #T_2e403_row6_col4, #T_2e403_row10_col11, #T_2e403_row11_col10, #T_2e403_row13_col15, #T_2e403_row14_col15, #T_2e403_row15_col13, #T_2e403_row15_col14 {
#   color: red;
# }
# </style>
# <table id="T_2e403_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >num_likes</th>
#       <th class="col_heading level0 col1" >num_comments</th>
#       <th class="col_heading level0 col2" >num_sent</th>
#       <th class="col_heading level0 col3" >sent_avg_length</th>
#       <
